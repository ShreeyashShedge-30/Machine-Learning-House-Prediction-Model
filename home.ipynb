# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv")
df
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('Area(sq.ft)')
plt.ylabel('Price(Us$)')
plt.scatter(df.Area, df.Price, color = 'red', marker = 'x')
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['Area']], df['Price'])
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
135.78767123 * 3300 + 180616.43835616432
# Out:
# 628715.7534151643

# %% [raw]
# Y = mx + b
# m = coefficent
# x = feature(area need to be calculated)
# c/b = intercept

# %%
135.78767123 * 1000 + 180616.43835616432
# Out:
# 316404.10958616436

# %%
d = pd.read_csv("newHomeData.csv")
d.head(3)
# Out:
#    Area
# 0  1000
# 1  1500
# 2  2300

# %%
p = reg.predict(d)

# %%
d['Prices'] = p

# %%
d.to_csv("prediction.csv")
